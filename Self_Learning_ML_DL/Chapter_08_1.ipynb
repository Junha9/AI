# %% [markdown]
# <a href="https://colab.research.google.com/github/Junha9/AI/blob/master/Self_Learning_ML_DL/Chapter_08_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import statements
import keras

# %%
# Convolution layer of keras
keras.layers.Conv2D(10, kernel_size=(3,3), activation='relu')
# Out:
# <Conv2D name=conv2d, built=False>

# %%
# We can add padding to the layer
keras.layers.Conv2D(10, kernel_size=(3, 3), activation='relu', padding='same')
# Out:
# <Conv2D name=conv2d_1, built=False>

# %%
# Also we can set stride for the padding.
keras.layers.Conv2D(10, kernel_size=(3,3), activation='relu', padding='same', strides=1)
# Out:
# <Conv2D name=conv2d_2, built=False>

# %%
# keras pooling layer.
keras.layers.MaxPooling2D(2)
# Out:
# <MaxPooling2D name=max_pooling2d_1, built=True>

# %%
# Max Pooling has strides of 2 and valid padding as default.
keras.layers.MaxPooling2D(2, strides=2, padding='valid')
# Out:
# <MaxPooling2D name=max_pooling2d, built=True>
